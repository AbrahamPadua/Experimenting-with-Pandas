# %%
import pandas as pd

# %%
df = pd.read_csv("Data.csv")

# %%
df.shape
# Out:
# (825, 6)

# %%
df.head()
# Out:
#    Rank                                             Major Degree Type  \
# 0     1                             Petroleum Engineering   Bachelors
# 1     2  Electrical Engineering & Computer Science (EECS)   Bachelors
# 2     3                  Applied Economics and Management   Bachelors
# 3     3                               Operations Research   Bachelors
# 4     5                                 Public Accounting   Bachelors
#
#   Early Career Salary Mid-Career Salary Meaning
# 0             $92,300          $182,000     69%
# 1            $101,200          $152,300     46%
# 2             $60,900          $139,600     67%
# 3             $78,400          $139,600     52%
# 4             $60,000          $138,800     49%

# %%
df.tail()
# Out:
#      Rank                                   Major Degree Type  \
# 820   821                    Recreational Therapy   Bachelors
# 821   822                       Child Development   Bachelors
# 822   823                 Middle School Education   Bachelors
# 823   824                  Educational Psychology   Bachelors
# 824   825  Early Childhood & Elementary Education   Bachelors
#
#     Early Career Salary Mid-Career Salary Meaning
# 820             $36,400           $49,200     82%
# 821             $35,500           $49,100     76%
# 822             $39,000           $48,300     73%
# 823             $34,600           $47,600       -
# 824             $36,200           $46,500     78%

# %%
df.isna()
# Out:
#       Rank  Major  Degree Type  Early Career Salary  Mid-Career Salary  \
# 0    False  False        False                False              False
# 1    False  False        False                False              False
# 2    False  False        False                False              False
# 3    False  False        False                False              False
# 4    False  False        False                False              False
# ..     ...    ...          ...                  ...                ...
# 820  False  False        False                False              False
# 821  False  False        False                False              False
# 822  False  False        False                False              False
# 823  False  False        False                False              False
# 824  False  False        False                False              False
#
#      Meaning
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ..       ...
# ...

# %%
df.dropna()
# Out:
#      Rank                                             Major Degree Type  \
# 0       1                             Petroleum Engineering   Bachelors
# 1       2  Electrical Engineering & Computer Science (EECS)   Bachelors
# 2       3                  Applied Economics and Management   Bachelors
# 3       3                               Operations Research   Bachelors
# 4       5                                 Public Accounting   Bachelors
# ..    ...                                               ...         ...
# 820   821                              Recreational Therapy   Bachelors
# 821   822                                 Child Development   Bachelors
# 822   823                           Middle School Education   Bachelors
# 823   824                            Educational Psychology   Bachelors
# 824   825            Early Childhood & Elementary Education   Bachelors
#
#     Early Career Salary Mid-Career Salary Meaning
# 0               $92,300          $182,000     69%
# ...
